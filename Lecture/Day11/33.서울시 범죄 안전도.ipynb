# %% [markdown]
# ### 서울시에서 일어나는 범죄와 체감 안전도
# : 강남3구 안전도가 얼마나 되는지 또한 서울시 전체의 안전도가 얼마나 되는지 확인

# %%
import pandas as pd

# %%
crime_anal_police = \
  pd.read_csv("./Data/crime_in_Seoul.csv", encoding='euc-kr') # utf-8, euc-kr
crime_anal_police.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65  1,395   477  1,355  1,170
# 1   종로서      3      3      6      5    115     98  1,070   413  1,278  1,070
# 2  남대문서      1      0      6      4     65     46  1,153   382    869    794
# 3  서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711
# 4   혜화서      3      2      5      4     96     63  1,114   424  1,015    861

# %%
crime_anal_police.tail()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 26  노원서     10     10      7      7    197    121  2,193   801  2,723  2,329
# 27  방배서      1      2      1      1     59     56    653   186    547    491
# 28  은평서      1      1      7      5     96     82  1,095   418  1,461  1,268
# 29  도봉서      3      3      9     10    102    106  1,063   478  1,487  1,303
# 30  수서서     10      7      6      6    149    124  1,439   666  1,819  1,559

# %%
crime_anal_police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   관서명     31 non-null     object
#  1   살인 발생   31 non-null     int64
#  2   살인 검거   31 non-null     int64
#  3   강도 발생   31 non-null     int64
#  4   강도 검거   31 non-null     int64
#  5   강간 발생   31 non-null     int64
#  6   강간 검거   31 non-null     int64
#  7   절도 발생   31 non-null     object
#  8   절도 검거   31 non-null     object
#  9   폭력 발생   31 non-null     object
#  10  폭력 검거   31 non-null     object
# dtypes: int64(6), object(5)
# memory usage: 2.8+ KB

# %% [markdown]
# > 절도발생, 절도검거, 폭력발생, 폭력검거는 dtype이 object이다.

# %%
# 경찰서 위치 정보
police_address = pd.read_csv("./Data/SeoulPoliceAddress.csv")
police_address.head()
# Out:
#        경찰관서           전화번호            FAX                  주소
# 0   서울중부경찰서  (02)2273-4400  (02)2275-3009        서울 중구 수표로 27
# 1   서울종로경찰서  (02)3701-4324  (02)3701-4223       서울 종로구 율곡로 46
# 2  서울남대문경찰서  (02)2096-8324  (02)2096-8337      서울 중구 한강대로 410
# 3  서울서대문경찰서   (02)335-8192   (02)335-8189     서울 서대문구 통일로 113
# 4   서울혜화경찰서   (02)762-4400  (02)3158-7133  서울 종로구 창경궁로 112-16

# %% [markdown]
# ### crime_anal_police의 관서명 데이터를 일치 시키기
# : 중부서 -> 서울중부경찰서

# %%
# Method 1
station_name = []

for name in crime_anal_police['관서명']:
  station_name.append("서울"+name[:-1]+"경찰서")

station_name
# Out:
# ['서울중부경찰서',
#  '서울종로경찰서',
#  '서울남대문경찰서',
#  '서울서대문경찰서',
#  '서울혜화경찰서',
#  '서울용산경찰서',
#  '서울성북경찰서',
#  '서울동대문경찰서',
#  '서울마포경찰서',
#  '서울영등포경찰서',
#  '서울성동경찰서',
#  '서울동작경찰서',
#  '서울광진경찰서',
#  '서울서부경찰서',
#  '서울강북경찰서',
#  '서울금천경찰서',
#  '서울중랑경찰서',
#  '서울강남경찰서',
#  '서울관악경찰서',
#  '서울강서경찰서',
#  '서울강동경찰서',
#  '서울종암경찰서',
#  '서울구로경찰서',
#  '서울서초경찰서',
#  '서울양천경찰서',
#  '서울송파경찰서',
#  '서울노원경찰서',
#  '서울방배경찰서',
#  '서울은평경찰서',
#  '서울도봉경찰서',
#  '서울수서경찰서']

# %%
# Method 2
station_name = \
  ["서울"+name[:-1]+"경찰서" for name in crime_anal_police['관서명']]
station_name
# Out:
# ['서울중부경찰서',
#  '서울종로경찰서',
#  '서울남대문경찰서',
#  '서울서대문경찰서',
#  '서울혜화경찰서',
#  '서울용산경찰서',
#  '서울성북경찰서',
#  '서울동대문경찰서',
#  '서울마포경찰서',
#  '서울영등포경찰서',
#  '서울성동경찰서',
#  '서울동작경찰서',
#  '서울광진경찰서',
#  '서울서부경찰서',
#  '서울강북경찰서',
#  '서울금천경찰서',
#  '서울중랑경찰서',
#  '서울강남경찰서',
#  '서울관악경찰서',
#  '서울강서경찰서',
#  '서울강동경찰서',
#  '서울종암경찰서',
#  '서울구로경찰서',
#  '서울서초경찰서',
#  '서울양천경찰서',
#  '서울송파경찰서',
#  '서울노원경찰서',
#  '서울방배경찰서',
#  '서울은평경찰서',
#  '서울도봉경찰서',
#  '서울수서경찰서']

# %%
# Method 3
station_name = list("서울" + crime_anal_police['관서명'].str[:-1] + "경찰서")
station_name
# Out:
# ['서울중부경찰서',
#  '서울종로경찰서',
#  '서울남대문경찰서',
#  '서울서대문경찰서',
#  '서울혜화경찰서',
#  '서울용산경찰서',
#  '서울성북경찰서',
#  '서울동대문경찰서',
#  '서울마포경찰서',
#  '서울영등포경찰서',
#  '서울성동경찰서',
#  '서울동작경찰서',
#  '서울광진경찰서',
#  '서울서부경찰서',
#  '서울강북경찰서',
#  '서울금천경찰서',
#  '서울중랑경찰서',
#  '서울강남경찰서',
#  '서울관악경찰서',
#  '서울강서경찰서',
#  '서울강동경찰서',
#  '서울종암경찰서',
#  '서울구로경찰서',
#  '서울서초경찰서',
#  '서울양천경찰서',
#  '서울송파경찰서',
#  '서울노원경찰서',
#  '서울방배경찰서',
#  '서울은평경찰서',
#  '서울도봉경찰서',
#  '서울수서경찰서']

# %%
# 확인
len(station_name)
# Out:
# 31

# %%
len(police_address)
# Out:
# 31

# %%
# 2개의 file에 경찰관서 이름이 동일한지 확인
len(station_name == police_address['경찰관서'])
# Out:
# 31

# %%
# 경찰서의 위도 경도 불러오기
station_latlng = pd.read_csv("./Data/policeStation_latlng.csv")
station_latlng.head()
# Out:
#          lat         lng
# 0  37.559674  126.979373
# 1  37.575873  126.984538
# 2  37.554819  126.973563
# 3  37.560481  126.962589
# 4  37.571876  126.998932

# %%
# police_address와 station_latlng 병합해서 police_address로 컬럼 넣기
police_address = \
  pd.merge(police_address, station_latlng, left_index=True, right_index=True)

police_address.head()
# Out:
#        경찰관서           전화번호            FAX                  주소        lat  \
# 0   서울중부경찰서  (02)2273-4400  (02)2275-3009        서울 중구 수표로 27  37.559674
# 1   서울종로경찰서  (02)3701-4324  (02)3701-4223       서울 종로구 율곡로 46  37.575873
# 2  서울남대문경찰서  (02)2096-8324  (02)2096-8337      서울 중구 한강대로 410  37.554819
# 3  서울서대문경찰서   (02)335-8192   (02)335-8189     서울 서대문구 통일로 113  37.560481
# 4   서울혜화경찰서   (02)762-4400  (02)3158-7133  서울 종로구 창경궁로 112-16  37.571876
#
#           lng
# 0  126.979373
# 1  126.984538
# 2  126.973563
# 3  126.962589
# 4  126.998932

# %% [markdown]
# ### 경찰서의 주소중 구이름만 추출하기

# %%
crime_anal_police['구별'] = [region.split()[1] for region in police_address['주소']]
crime_anal_police.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거  \
# 0   중부서      2      2      3      2    105     65  1,395   477  1,355  1,170
# 1   종로서      3      3      6      5    115     98  1,070   413  1,278  1,070
# 2  남대문서      1      0      6      4     65     46  1,153   382    869    794
# 3  서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711
# 4   혜화서      3      2      5      4     96     63  1,114   424  1,015    861
#
#      구별
# 0    중구
# 1   종로구
# 2    중구
# 3  서대문구
# 4   종로구

# %%
len(crime_anal_police['구별'])
# Out:
# 31

# %%
# 중복값 확인
len(set(crime_anal_police['구별']))
# Out:
# 23

# %% [markdown]
# > 서울시 구는 25개구로 되어 있는데 23개의 구만 보임
# 서울시 구는 25개구로 되어 있는데 경찰서 수는 31개로 동일한 구에 경찰서가 1개 이상 있는 지역이 있다.

# %%
# 관서명과 구별 이름 확인 
crime_anal_police.loc[:,['관서명','구별']]
# Out:
#      관서명    구별
# 0    중부서    중구
# 1    종로서   종로구
# 2   남대문서    중구
# 3   서대문서  서대문구
# 4    혜화서   종로구
# 5    용산서   용산구
# 6    성북서   성북구
# 7   동대문서  동대문구
# 8    마포서   마포구
# 9   영등포서  영등포구
# 10   성동서   성동구
# 11   동작서   동작구
# 12   광진서   광진구
# 13   서부서   은평구
# 14   강북서   강북구
# 15   금천서   관악구
# 16   중랑서   중랑구
# 17   강남서   강남구
# 18   관악서   관악구
# 19   강서서   양천구
# 20   강동서   강동구
# 21   종암서   성북구
# 22   구로서   구로구
# 23   서초서   서초구
# 24   양천서   양천구
# 25   송파서   송파구
# 26   노원서   노원구
# 27   방배서   서초구
# 28   은평서   은평구
# 29   도봉서   도봉구
# 30   수서서   강남구

# %%
# 금천서의 관악구 -> 금천서의 금천구 
crime_anal_police[crime_anal_police['관서명']=='금천서']
crime_anal_police.loc[crime_anal_police['관서명']=='금천서','구별'] = '금천구'
crime_anal_police[crime_anal_police['관서명']=='금천서']
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거  \
# 15  금천서      3      4      6      6    151    122  1,567   888  2,054  1,776
#
#      구별
# 15  금천구

# %%
# 강서서의 양천구 -> 강서서의 강서구로 변경
crime_anal_police[crime_anal_police['관서명']=='강서서']
crime_anal_police.loc[crime_anal_police['관서명']=='강서서','구별'] = '강서구'
crime_anal_police[crime_anal_police['관서명']=='강서서']
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 19  강서서      7      8     13     13    262    191  2,096  1,260  3,207  2,718
#
#      구별
# 19  강서구

# %%
len(set(crime_anal_police['구별']))
# Out:
# 25

# %% [markdown]
# > 관서명으로 데이터를 정리하는 것이 아니고 구별로 데이터를 정리했다.

# %%
crime_anal_police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   관서명     31 non-null     object
#  1   살인 발생   31 non-null     int64
#  2   살인 검거   31 non-null     int64
#  3   강도 발생   31 non-null     int64
#  4   강도 검거   31 non-null     int64
#  5   강간 발생   31 non-null     int64
#  6   강간 검거   31 non-null     int64
#  7   절도 발생   31 non-null     object
#  8   절도 검거   31 non-null     object
#  9   폭력 발생   31 non-null     object
#  10  폭력 검거   31 non-null     object
#  11  구별      31 non-null     object
# dtypes: int64(6), object(6)
# memory usage: 3.0+ KB

# %%
# 절도발생 부터 폭력검거까지의 dtype을 int로 변환

crime_anal_police['절도 발생'] = \
  crime_anal_police['절도 발생'].str.replace(",","").astype(int)

crime_anal_police['절도 검거'] = \
  crime_anal_police['절도 검거'].str.replace(",","").astype(int)

crime_anal_police['폭력 검거'] = \
  crime_anal_police['폭력 검거'].str.replace(",","").astype(int)

crime_anal_police['폭력 발생'] = \
  crime_anal_police['폭력 발생'].str.replace(",","").astype(int)

crime_anal_police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   관서명     31 non-null     object
#  1   살인 발생   31 non-null     int64
#  2   살인 검거   31 non-null     int64
#  3   강도 발생   31 non-null     int64
#  4   강도 검거   31 non-null     int64
#  5   강간 발생   31 non-null     int64
#  6   강간 검거   31 non-null     int64
#  7   절도 발생   31 non-null     int32
#  8   절도 검거   31 non-null     int32
#  9   폭력 발생   31 non-null     int32
#  10  폭력 검거   31 non-null     int32
#  11  구별      31 non-null     object
# dtypes: int32(4), int64(6), object(2)
# memory usage: 2.6+ KB

# %% [markdown]
# # 구별로 데이터를 정리한다.

# %%
crime_anal = pd.pivot_table(crime_anal_police, index='구별', aggfunc='sum')
crime_anal.head()
# Out:
#      강간 검거  강간 발생  강도 검거  강도 발생     관서명  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  \
# 구별
# 강남구    349    449     18     21  강남서수서서     10     13   1650   3850   3705
# 강동구    123    156      8      6     강동서      3      4    789   2366   2248
# 강북구    126    153     13     14     강북서      8      7    618   1434   2348
# 강서구    191    262     13     13     강서서      8      7   1260   2096   2718
# 관악구    221    320     14     12     관악서      8      9    827   2706   2642
#
#      폭력 발생
# 구별
# 강남구   4284
# 강동구   2712
# 강북구   2649
# 강서구   3207
# 관악구   3298

# %%
# 각 범죄별 검거율 구하기
crime_anal['강간검거율'] = crime_anal['강간 검거'] / crime_anal['강간 발생'] * 100
crime_anal['강도검거율'] = crime_anal['강도 검거'] / crime_anal['강도 발생'] * 100
crime_anal['살인검거율'] = crime_anal['살인 검거'] / crime_anal['살인 발생'] * 100
crime_anal['절도검거율'] = crime_anal['절도 검거'] / crime_anal['절도 발생'] * 100
crime_anal['폭력검거율'] = crime_anal['폭력 검거'] / crime_anal['폭력 발생'] * 100

crime_anal.head()
# Out:
#      강간 검거  강간 발생  강도 검거  강도 발생     관서명  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  \
# 구별
# 강남구    349    449     18     21  강남서수서서     10     13   1650   3850   3705
# 강동구    123    156      8      6     강동서      3      4    789   2366   2248
# 강북구    126    153     13     14     강북서      8      7    618   1434   2348
# 강서구    191    262     13     13     강서서      8      7   1260   2096   2718
# 관악구    221    320     14     12     관악서      8      9    827   2706   2642
#
#      폭력 발생      강간검거율       강도검거율       살인검거율      절도검거율      폭력검거율
# 구별
# 강남구   4284  77.728285   85.714286   76.923077  42.857143  86.484594
# 강동구   2712  78.846154  133.333333   75.000000  33.347422  82.890855
# 강북구   2649  82.352941   92.857143  114.285714  43.096234  88.637222
# 강서구   3207  72.900763  100.000000  114.285714  60.114504  84.752105
# 관악구   3298  69.062500  116.666667   88.888889  30.561715  80.109157

# %%
# 검거 컬럼은 삭제
del crime_anal['강간 검거']
del crime_anal['강도 검거']
del crime_anal['살인 검거']
del crime_anal['절도 검거']
del crime_anal['폭력 검거']

crime_anal.head()
# Out:
#      강간 발생  강도 발생     관서명  살인 발생  절도 발생  폭력 발생      강간검거율       강도검거율  \
# 구별
# 강남구    449     21  강남서수서서     13   3850   4284  77.728285   85.714286
# 강동구    156      6     강동서      4   2366   2712  78.846154  133.333333
# 강북구    153     14     강북서      7   1434   2649  82.352941   92.857143
# 강서구    262     13     강서서      7   2096   3207  72.900763  100.000000
# 관악구    320     12     관악서      9   2706   3298  69.062500  116.666667
#
#           살인검거율      절도검거율      폭력검거율
# 구별
# 강남구   76.923077  42.857143  86.484594
# 강동구   75.000000  33.347422  82.890855
# 강북구  114.285714  43.096234  88.637222
# 강서구  114.285714  60.114504  84.752105
# 관악구   88.888889  30.561715  80.109157

# %%
# 전년도 발생한 사건의 검거 건수도 포함되어서 검거율이 100이 넘는곳이 발생한다.
crime_anal.loc[crime_anal['강간검거율'] > 100, '강간검거율'] = 100
crime_anal.loc[crime_anal['강도검거율'] > 100, '강도검거율'] = 100
crime_anal.loc[crime_anal['절도검거율'] > 100, '절도검거율'] = 100
crime_anal.loc[crime_anal['살인검거율'] > 100, '살인검거율'] = 100
crime_anal.loc[crime_anal['폭력검거율'] > 100, '폭력검거율'] = 100

crime_anal.head()
# Out:
#      강간 발생  강도 발생     관서명  살인 발생  절도 발생  폭력 발생      강간검거율       강도검거율  \
# 구별
# 강남구    449     21  강남서수서서     13   3850   4284  77.728285   85.714286
# 강동구    156      6     강동서      4   2366   2712  78.846154  100.000000
# 강북구    153     14     강북서      7   1434   2649  82.352941   92.857143
# 강서구    262     13     강서서      7   2096   3207  72.900763  100.000000
# 관악구    320     12     관악서      9   2706   3298  69.062500  100.000000
#
#           살인검거율      절도검거율      폭력검거율
# 구별
# 강남구   76.923077  42.857143  86.484594
# 강동구   75.000000  33.347422  82.890855
# 강북구  100.000000  43.096234  88.637222
# 강서구  100.000000  60.114504  84.752105
# 관악구   88.888889  30.561715  80.109157

# %%
# Column 이름 변경
crime_anal.rename(
  columns={
    '강간 발생' : '강간',
    '강도 발생' : '강도',
    '절도 발생' : '절도',
    '폭력 발생' : '폭력',
    '살인 발생' : '살인'
  },
  inplace=True
)

crime_anal.head()
# Out:
#       강간  강도     관서명  살인    절도    폭력      강간검거율       강도검거율       살인검거율  \
# 구별
# 강남구  449  21  강남서수서서  13  3850  4284  77.728285   85.714286   76.923077
# 강동구  156   6     강동서   4  2366  2712  78.846154  100.000000   75.000000
# 강북구  153  14     강북서   7  1434  2649  82.352941   92.857143  100.000000
# 강서구  262  13     강서서   7  2096  3207  72.900763  100.000000  100.000000
# 관악구  320  12     관악서   9  2706  3298  69.062500  100.000000   88.888889
#
#          절도검거율      폭력검거율
# 구별
# 강남구  42.857143  86.484594
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 강서구  60.114504  84.752105
# 관악구  30.561715  80.109157

# %% [markdown]
# ---
# ### 데이터의 정규화 (Normalization)
# - 강도와 살인은 2자릿수이나 절도와 폭력은 4자리 입니다.
# - 각 범죄의 건수를 비슷한 범위에 놓고 비교해야 합니다.
# - 각 항목의 값을 최대 1로 계산하여 비중 자체로 분석해야 합니다.

# %%
# 머신러닝 모듈 사용하기
from sklearn import preprocessing

# %%
# 정규화를 진행할 컬럼 설정
col = ['강간','강도','살인','절도','폭력']

# %%
# 정규화를 진행할 컬럼의 데이터
x = crime_anal[col].values
x
# Out:
# array([[ 449,   21,   13, 3850, 4284],
#        [ 156,    6,    4, 2366, 2712],
#        [ 153,   14,    7, 1434, 2649],
#        [ 262,   13,    7, 2096, 3207],
#        [ 320,   12,    9, 2706, 3298],
#        [ 240,   14,    4, 3026, 2625],
#        [ 281,   15,    8, 2335, 3007],
#        [ 151,    6,    3, 1567, 2054],
#        [ 197,    7,   10, 2193, 2723],
#        [ 102,    9,    3, 1063, 1487],
#        [ 173,   13,    5, 1981, 2548],
#        [ 285,    9,    5, 1865, 1910],
#        [ 294,   14,    8, 2555, 2983],
#        [ 154,    5,    2, 1812, 2056],
#        [ 393,    9,    8, 2635, 2399],
#        [ 126,    9,    4, 1607, 1612],
#        [ 150,    5,    5, 1785, 2209],
#        [ 220,   13,   11, 3239, 3295],
#        [ 120,    6,    3, 1890, 2509],
#        [ 295,   22,   14, 2964, 3572],
#        [ 194,   14,    5, 1557, 2050],
#        [ 166,    9,    3, 1914, 2653],
#        [ 211,   11,    6, 2184, 2293],
#        [ 170,    9,    3, 2548, 2224],
# ...

# %%
# 최대값과 최소값 
min_max_scaler = preprocessing.MinMaxScaler()
min_max_scaler
# Out:
# MinMaxScaler()

# %%
# 정규화 시킬 최종값을 비율로 계산되기 때문에 입력데이터를 float로 변경
x_scaled = min_max_scaler.fit_transform(x.astype(float))
x_scaled
# Out:
# array([[1.        , 0.94117647, 0.91666667, 1.        , 1.        ],
#        [0.1556196 , 0.05882353, 0.16666667, 0.46752781, 0.43796925],
#        [0.14697406, 0.52941176, 0.41666667, 0.13311805, 0.41544512],
#        [0.4610951 , 0.47058824, 0.41666667, 0.37064944, 0.61494458],
#        [0.62824207, 0.41176471, 0.58333333, 0.58952278, 0.64747944],
#        [0.39769452, 0.52941176, 0.16666667, 0.70434159, 0.4068645 ],
#        [0.51585014, 0.58823529, 0.5       , 0.45640474, 0.5434394 ],
#        [0.14121037, 0.05882353, 0.08333333, 0.18083961, 0.2027172 ],
#        [0.27377522, 0.11764706, 0.66666667, 0.40545389, 0.44190204],
#        [0.        , 0.23529412, 0.08333333, 0.        , 0.        ],
#        [0.20461095, 0.47058824, 0.25      , 0.32938644, 0.379335  ],
#        [0.52737752, 0.23529412, 0.25      , 0.28776462, 0.15123346],
#        [0.55331412, 0.52941176, 0.5       , 0.53534266, 0.53485878],
#        [0.14985591, 0.        , 0.        , 0.26874776, 0.20343225],
# ...

# %%
# 정규화된 범죄건수가 있는 새로운 데이터 프레임 생성
crime_anal_norm = pd.DataFrame(x_scaled, columns=col, index=crime_anal.index)
crime_anal_norm
# Out:
#             강간        강도        살인        절도        폭력
# 구별
# 강남구   1.000000  0.941176  0.916667  1.000000  1.000000
# 강동구   0.155620  0.058824  0.166667  0.467528  0.437969
# 강북구   0.146974  0.529412  0.416667  0.133118  0.415445
# 강서구   0.461095  0.470588  0.416667  0.370649  0.614945
# 관악구   0.628242  0.411765  0.583333  0.589523  0.647479
# 광진구   0.397695  0.529412  0.166667  0.704342  0.406864
# 구로구   0.515850  0.588235  0.500000  0.456405  0.543439
# 금천구   0.141210  0.058824  0.083333  0.180840  0.202717
# 노원구   0.273775  0.117647  0.666667  0.405454  0.441902
# 도봉구   0.000000  0.235294  0.083333  0.000000  0.000000
# 동대문구  0.204611  0.470588  0.250000  0.329386  0.379335
# 동작구   0.527378  0.235294  0.250000  0.287765  0.151233
# 마포구   0.553314  0.529412  0.500000  0.535343  0.534859
# 서대문구  0.149856  0.000000  0.000000  0.268748  0.203432
# 서초구   0.838617  0.235294  0.500000  0.564047  0.326064
# 성동구   0.069164  0.235294  0.166667  0.195192  0.044691
# ...

# %%
col2 = ['강간검거율','강도검거율','살인검거율','절도검거율','폭력검거율']
crime_anal_norm[col2] = crime_anal[col2]
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  1.000000  1.000000  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.467528  0.437969  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.133118  0.415445  82.352941   92.857143
# 강서구  0.461095  0.470588  0.416667  0.370649  0.614945  72.900763  100.000000
# 관악구  0.628242  0.411765  0.583333  0.589523  0.647479  69.062500  100.000000
#
#           살인검거율      절도검거율      폭력검거율
# 구별
# 강남구   76.923077  42.857143  86.484594
# 강동구   75.000000  33.347422  82.890855
# 강북구  100.000000  43.096234  88.637222
# 강서구  100.000000  60.114504  84.752105
# 관악구   88.888889  30.561715  80.109157

# %% [markdown]
# ### Seaborn을 활용한 시각화

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform
# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# 시각화 도구
from matplotlib import pyplot as plt
# %matplotlib inline

# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# 강간, 강도, 살인, 폭력, 절도 건수에 대한 상관관계 시각화
sns.pairplot(
  crime_anal_norm,
  vars=['강간','강도','살인','폭력','절도'],
  kind='reg' # regression
)
plt.show()

# %% [markdown]
# > 5대범죄 모두 양의 상관관계
# 예를 들어 강도의 건수의 많아지면 폭력과 살인의 발생건수도 많아진다.

# %% [markdown]
# ### heatmap을 이용한 전체 검거율 확인

# %%
import numpy as np

# %%
# 검거율 통합
col = ['강간검거율','강도검거율','살인검거율','절도검거율','폭력검거율']
crime_anal_norm['검거'] = np.sum(crime_anal_norm[col], axis=1)
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  1.000000  1.000000  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.467528  0.437969  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.133118  0.415445  82.352941   92.857143
# 강서구  0.461095  0.470588  0.416667  0.370649  0.614945  72.900763  100.000000
# 관악구  0.628242  0.411765  0.583333  0.589523  0.647479  69.062500  100.000000
#
#           살인검거율      절도검거율      폭력검거율          검거
# 구별
# 강남구   76.923077  42.857143  86.484594  369.707384
# 강동구   75.000000  33.347422  82.890855  370.084431
# 강북구  100.000000  43.096234  88.637222  406.943540
# 강서구  100.000000  60.114504  84.752105  417.767372
# 관악구   88.888889  30.561715  80.109157  368.622261

# %%
# 검거의 최대값
tmp_max = crime_anal_norm['검거'].max()
crime_anal_norm['검거'] = crime_anal_norm['검거'] / tmp_max
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  1.000000  1.000000  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.467528  0.437969  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.133118  0.415445  82.352941   92.857143
# 강서구  0.461095  0.470588  0.416667  0.370649  0.614945  72.900763  100.000000
# 관악구  0.628242  0.411765  0.583333  0.589523  0.647479  69.062500  100.000000
#
#           살인검거율      절도검거율      폭력검거율        검거
# 구별
# 강남구   76.923077  42.857143  86.484594  0.854631
# 강동구   75.000000  33.347422  82.890855  0.855502
# 강북구  100.000000  43.096234  88.637222  0.940707
# 강서구  100.000000  60.114504  84.752105  0.965728
# 관악구   88.888889  30.561715  80.109157  0.852122

# %%
crime_anal_norm_sort = crime_anal_norm.sort_values(by='검거', ascending=False)
crime_anal_norm_sort.head()
# Out:
#             강간        강도        살인        절도        폭력       강간검거율  강도검거율  \
# 구별
# 도봉구   0.000000  0.235294  0.083333  0.000000  0.000000  100.000000  100.0
# 금천구   0.141210  0.058824  0.083333  0.180840  0.202717   80.794702  100.0
# 강서구   0.461095  0.470588  0.416667  0.370649  0.614945   72.900763  100.0
# 광진구   0.397695  0.529412  0.166667  0.704342  0.406864   91.666667  100.0
# 동대문구  0.204611  0.470588  0.250000  0.329386  0.379335   84.393064  100.0
#
#       살인검거율      절도검거율      폭력검거율        검거
# 구별
# 도봉구   100.0  44.967074  87.626093  1.000000
# 금천구   100.0  56.668794  86.465433  0.979971
# 강서구   100.0  60.114504  84.752105  0.965728
# 광진구   100.0  42.200925  83.047619  0.963758
# 동대문구  100.0  41.090358  87.401884  0.954443

# %%
target_col = ['강간검거율','강도검거율','살인검거율','절도검거율','폭력검거율']
plt.figure(figsize=(10, 10))

sns.heatmap(
  crime_anal_norm_sort[target_col],
  annot=True,
  fmt='f',
  annot_kws={'size':10}
)

plt.title('범죄 검거 비율')
plt.show()
